# %% [markdown]
# # Stage 6. Evaluation and Ablation
#
# Notebook ini menghitung metrik regresi, klasifikasi, dan severity, menyusun tabel generalisasi lintas dataset, serta menjalankan studi ablation untuk memverifikasi kontribusi tiap modul.

# %% [markdown]
# ## Environment Setup

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from configs import paths
from src import eval as evaluation
